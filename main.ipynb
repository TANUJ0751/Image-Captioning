# %% [markdown]
# Start

# %%
from os import listdir
from pickle import dump
from keras.applications.vgg16 import VGG16 as VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model 
print("Done")
# Out:
# Done

# %%
def extract_features(directory):
    #Load the Model
    model = VGG16()
    #re structure the model
    model.layers.pop()
    model = Model(inputs = model.inputs, outputs=model.layers[-1].output)
    #summarize
    print(model.summary())
    # extract features form each photo
    features=dict()
    for name in listdir(directory):
        filename=directory+'/'+name
        image=load_img(filename,target_size=(224,224))
        image=img_to_array(image)
        image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
        image=preprocess_input(image)
        feature = model.predict(image, verbose=0)
        image_id= name.split('.')[0]
        features[image_id]=feature
        print('>%s' % name)
    return features
#extract features from all images
directory='Images'
features=extract_features(directory)
print('Extracted Features: %d'% len(features))
#save to file
dump(features,open('features.pkl','wb'))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 1000)           │     4,097,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 138,357,544 (527.79 MB)
#  Trainable params: 138,357,544 (527.79 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# C:\Users\TANUJ\anaconda3\envs\imgcapt\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# >1000268201_693b08cb0e.jpg
# >1001773457_577c3a7d70.jpg
# >1002674143_1b742ab4b8.jpg
# >1003163366_44323f5815.jpg
# >1007129816_e794419615.jpg
# >1007320043_627395c3d8.jpg
# >1009434119_febe49276a.jpg
# >1012212859_01547e3f17.jpg
# >1015118661_980735411b.jpg
# >1015584366_dfcec3c85a.jpg
# >101654506_8eb26cfb60.jpg
# >101669240_b2d3e7f17b.jpg
# >1016887272_03199f49c4.jpg
# >1019077836_6fc9b15408.jpg
# >1019604187_d087bf9a5f.jpg
# >1020651753_06077ec457.jpg
# >1022454332_6af2c1449a.jpg
# >1022454428_b6b660a67b.jpg
# >1022975728_75515238d8.jpg
# >102351840_323e3de834.jpg
# >1024138940_f1fefbdce1.jpg
# >102455176_5f8ead62d5.jpg
# >1026685415_0431cbf574.jpg
# >1028205764_7e8df9a2ea.jpg
# >1030985833_b0902ea560.jpg
# >103106960_e8a41d64f8.jpg
# >103195344_5d2dc613a3.jpg
# >103205630_682ca7285b.jpg
# >1032122270_ea6f0beedb.jpg
# >1032460886_4a598ed535.jpg
# >1034276567_49bb87c51c.jpg
# >104136873_5b5d41be75.jpg
# >1042020065_fb3d3ba5ba.jpg
# >1042590306_95dea0916c.jpg
# >1045521051_108ebc19be.jpg
# >1048710776_bb5b0a5c7c.jpg
# >1052358063_eae6744153.jpg
# >105342180_4d4a40b47f.jpg
# >1053804096_ad278b25f1.jpg
# >1055623002_8195a43714.jpg
# >1055753357_4fa3d8d693.jpg
# >1056249424_ef2a2e041c.jpg
# >1056338697_4f7d7ce270.jpg
# >1056359656_662cee0814.jpg
# >1056873310_49c665eb22.jpg
# >1057089366_ca83da0877.jpg
# >1057210460_09c6f4c6c1.jpg
# >1057251835_6ded4ada9c.jpg
# >106490881_5a2dd9b7bd.jpg
# >106514190_bae200f463.jpg
# >1067180831_a59dc64344.jpg
# >1067675215_7336a694d6.jpg
# >1067790824_f3cc97239b.jpg
# >1072153132_53d2bb1b60.jpg
# >107318069_e9f2ef32de.jpg
# >1075716537_62105738b4.jpg
# >107582366_d86f2d3347.jpg
# >1075867198_27ca2e7efe.jpg
# >1075881101_d55c46bece.jpg
# >1077546505_a4f6c4daa9.jpg
# >1077931201_1e0bb83105.jpg
# >1079274291_9aaf896cc1.jpg
# >10815824_2997e03d76.jpg
# >1082252566_8c79beef93.jpg
# >1082379191_ec1e53f996.jpg
# >1084040636_97d9633581.jpg
# >1084104085_3b06223afe.jpg
# >1087168168_70280d024a.jpg
# >1087539207_9f77ab3aaf.jpg
# >1088767354_2acee738cf.jpg
# >108898978_7713be88fc.jpg
# >108899015_bf36131a57.jpg
# >1089181217_ee1167f7af.jpg
# >1089755335_0bfbfd30e6.jpg
# >109202756_b97fcdc62c.jpg
# >109202801_c6381eef15.jpg
# >109260216_85b0be5378.jpg
# >109260218_fca831f933.jpg
# >1093716555_801aacef79.jpg
# >1093737381_b313cd49ff.jpg
# >1094462889_f9966dafa6.jpg
# >1095476286_87d4f8664e.jpg
# >1095580424_76f0aa8a3e.jpg
# >1095590286_c654f7e5a9.jpg
# >1095980313_3c94799968.jpg
# >1096097967_ac305887b4.jpg
# >1096165011_cc5eb16aa6.jpg
# >1096395242_fc69f0ae5a.jpg
# >109671650_f7bbc297fa.jpg
# >109738763_90541ef30d.jpg
# >109738916_236dc456ac.jpg
# >109823394_83fcb735e1.jpg
# >109823395_6fb423a90f.jpg
# >109823397_e35154645f.jpg
# >1100214449_d10861e633.jpg
# >1104133405_c04a00707f.jpg
# >1105959054_9c3a738096.jpg
# >110595925_f3395c8bd6.jpg
# >1107246521_d16a476380.jpg
# >1107471216_4336c9b328.jpg
# >1110208841_5bb6806afe.jpg
# >1112212364_0c48235fc2.jpg
# >111497985_38e9f88856.jpg
# >111537217_082a4ba060.jpg
# >111537222_07e56d5a30.jpg
# >1115565519_d976d4b1f1.jpg
# >1115679311_245eff2f4b.jpg
# >111766423_4522d36e56.jpg
# >1117972841_2b9261f95f.jpg
# >1118557877_736f339752.jpg
# >1119015538_e8e796281e.jpg
# >1119418776_58e4b93eac.jpg
# >1119463452_69d4eecd08.jpg
# >1121416483_c7902d0d49.jpg
# >112178718_87270d9b4d.jpg
# >112243673_fd68255217.jpg
# >1122944218_8eb3607403.jpg
# >1124448967_2221af8dc5.jpg
# >1129704496_4a61441f2c.jpg
# >1130017585_1a219257ac.jpg
# >1130369873_d80a1aa59c.jpg
# >1130401779_8c30182e3e.jpg
# >1131155939_b4b457b05e.jpg
# >1131340021_83f46b150a.jpg
# >1131800850_89c7ffd477.jpg
# >1131804997_177c3c0640.jpg
# >1131932671_c8d17751b3.jpg
# >1132772170_600610c5df.jpg
# >113678030_87a6a6e42e.jpg
# >1138784872_69ade3f2ab.jpg
# >114051287_dd85625a04.jpg
# >1141718391_24164bf1b1.jpg
# >1141739219_2c47195e4c.jpg
# >1142283988_6b227c5231.jpg
# >1142847777_2a0c1c2551.jpg
# >1143373711_2e90b7b799.jpg
# >1143882946_1898d2eeb9.jpg
# >1144288288_e5c9558b6a.jpg
# >1148238960_f8cacec2fc.jpg
# >1149179852_acad4d7300.jpg
# >114949897_490ca7eaec.jpg
# >1151466868_3bc4d9580b.jpg
# >1153704539_542f7aa3a5.jpg
# >1155138244_859fd6e079.jpg
# >115684808_cb01227802.jpg
# >1159574340_99ba8c3c59.jpg
# >1160034462_16b38174fe.jpg
# >1160441615_fe6b3c5277.jpg
# >1163282319_b729b24c46.jpg
# >116409198_0fe0c94f3b.jpg
# >1164131282_b30926f332.jpg
# >1164765687_7aca07bbe7.jpg
# >1167662968_e466f1e80a.jpg
# >1167669558_87a8a467d6.jpg
# >1167908324_8caab45e15.jpg
# >1169307342_e7a4685a5c.jpg
# >1174525839_7c1e6cfa86.jpg
# >1174629344_a2e1a2bdbf.jpg
# >1176580356_9810d877bf.jpg
# >1177994172_10d143cb8d.jpg
# >1178705300_c224d9a4f1.jpg
# >118187095_d422383c81.jpg
# >118309463_a532b75be9.jpg
# >1184967930_9e29ce380d.jpg
# >1187435567_18173c148b.jpg
# >1187593464_ce862352c6.jpg
# >1189977786_4f5aaed773.jpg
# >1191338263_a4fa073154.jpg
# >1193116658_c0161c35b5.jpg
# >119534510_d52b3781a3.jpg
# >1197800988_7fb0ca4888.jpg
# >1198194316_543cc7b945.jpg
# >1204996216_71d7519d9a.jpg
# >1206506157_c7956accd5.jpg
# >1207159468_425b902bfb.jpg
# >1211015912_9f3ee3a995.jpg
# >1213336750_2269b51397.jpg
# >1215334959_b1970965f7.jpg
# >121800200_bef08fae5f.jpg
# >121971540_0a986ee176.jpg
# >1220401002_3f44b1f3f7.jpg
# >1222322358_225067636e.jpg
# >1224851143_33bcdd299c.jpg
# >1225443522_1633e7121f.jpg
# >1227655020_b11a1bb112.jpg
# >1229756013_94663527d7.jpg
# >1231229740_8dcbf80bfb.jpg
# >1232148178_4f45cc3284.jpg
# >1234293791_6566284bcd.jpg
# >1234817607_924893f6e1.jpg
# >1235580648_7eebaed9bc.jpg
# >1235681222_819231767a.jpg
# >1235685934_be89b231fb.jpg
# >1236951314_0308dc4138.jpg
# >1236964638_1808784a3c.jpg
# >1237985362_dbafc59280.jpg
# >123889082_d3751e0350.jpg
# >123997871_6a9ca987b1.jpg
# >1240297429_c36ae0c58f.jpg
# >124195430_d14028660f.jpg
# >1244140539_da4804d828.jpg
# >1244306891_8e78ae1620.jpg
# >1244485675_822e6efe60.jpg
# >1245022983_fb329886dd.jpg
# >1247181182_35cabd76f3.jpg
# >1248357227_2b4175fc39.jpg
# >1248734482_3038218f3b.jpg
# >124881487_36e668145d.jpg
# >1248940539_46d33ed487.jpg
# >1248953128_24c9f8d924.jpg
# >124972799_de706b6d0b.jpg
# >1251558317_4ef844b775.jpg
# >1252396628_eb81d3905b.jpg
# >1252787177_4b08625897.jpg
# >125319704_49ead3463c.jpg
# >1253264731_e7c689eca5.jpg
# >1253275679_e955fb7304.jpg
# >1255504166_f2437febcb.jpg
# >1258913059_07c613f7ff.jpg
# >1259936608_e3f0064f23.jpg
# >1260816604_570fc35836.jpg
# >1262077938_8b9516c273.jpg
# >1262454669_f1caafec2d.jpg
# >1262583859_653f1469a9.jpg
# >1263126002_881ebd7ac9.jpg
# >1263801010_5c74bf1715.jpg
# >1267711451_e2a754b4f8.jpg
# >1269470943_ba7fc49b4d.jpg
# >1271210445_7f7ecf3791.jpg
# >1271960365_e54033f883.jpg
# >1273001772_1585562051.jpg
# >127450902_533ceeddfc.jpg
# >127488876_f2d2a89588.jpg
# >127490019_7c5c08cb11.jpg
# >1277185009_06478dd457.jpg
# >1277743944_f4e8c78403.jpg
# >1280147517_98767ca3b3.jpg
# >1280320287_b2a4b9b7bd.jpg
# >1282392036_5a0328eb86.jpg
# >12830823_87d2654e31.jpg
# >1285067106_2adc307240.jpg
# >1285874746_486731a954.jpg
# >1286408831_05282582ed.jpg
# >1287064529_aa4e4f3c31.jpg
# >1287073593_f3d2a62455.jpg
# >1287475186_2dee85f1a5.jpg
# >1287920676_d21a0b289b.jpg
# >1287931016_fb015e2e10.jpg
# >1287982439_6578006e22.jpg
# >1288909046_d2b2b62607.jpg
# >128912885_8350d277a4.jpg
# >1289142574_2bd6a082dd.jpg
# >1290894194_8a4ffdc7eb.jpg
# >1294578091_2ad02fea91.jpg
# >1295669416_21cabf594d.jpg
# >1295671216_cde1b9c9d1.jpg
# >1295698260_e10c53c137.jpg
# >129599450_cab4e77343.jpg
# >1296412797_85b6d2f8d6.jpg
# >1296770308_3db2022f5a.jpg
# >1298295313_db1f4c6522.jpg
# >1298866571_b4c496b71c.jpg
# >1299459550_1fd5594fa2.jpg
# >1299459562_ed0e064aee.jpg
# >1301140633_046e4e8010.jpg
# >130211457_be3f6b335d.jpg
# >1302657647_46b36c0d66.jpg
# >1303335399_b3facd47ab.jpg
# >1303548017_47de590273.jpg
# >1303550623_cb43ac044a.jpg
# >1303727066_23d0f6ed43.jpg
# >1303727828_d1052ee341.jpg
# >1304100320_c8990a1539.jpg
# >1304961697_76b86b0c18.jpg
# >1305564994_00513f9a5b.jpg
# >1306145560_1e37081b91.jpg
# >1307635496_94442dc21a.jpg
# >1308472581_9961782889.jpg
# >1308617539_54e1a3dfbe.jpg
# >1309330801_aeeb23f1ee.jpg
# >1311132744_5ffd03f831.jpg
# >1311388430_4ab0cd1a1f.jpg
# >1312020846_5abb4a9be2.jpg
# >1312227131_771b5ed201.jpg
# >1312954382_cf6d70d63a.jpg
# >1313693129_71d0b21c63.jpg
# >1313961775_824b87d155.jpg
# >1316247213_1d2c726dd5.jpg
# >131632409_4de0d4e710.jpg
# >1317292658_ba29330a0b.jpg
# >1319634306_816f21677f.jpg
# >1321723162_9d4c78b8af.jpg
# >1321949151_77b77b4617.jpg
# >1322323208_c7ecb742c6.jpg
# >1324816249_86600a6759.jpg
# >132489044_3be606baf7.jpg
# >1329832826_432538d331.jpg
# >1330645772_24f831ff8f.jpg
# >133189853_811de6ab2a.jpg
# >1332208215_fa824f6659.jpg
# >1332492622_8c66992b62.jpg
# >1332722096_1e3de8ae70.jpg
# >1332815795_8eea44375e.jpg
# >1332823164_c70a5d930e.jpg
# >1333888922_26f15c18c3.jpg
# >1334892555_1beff092c3.jpg
# >1335617803_4fbc03dab0.jpg
# >1337792872_d01a390b33.jpg
# >1338523142_57fce8229b.jpg
# >133905560_9d012b47f3.jpg
# >1339596997_8ac29c1841.jpg
# >1341787777_4f1ebb1793.jpg
# >1342766791_1e72f92455.jpg
# >1342780478_bacc32344d.jpg
# >1343426964_cde3fb54e8.jpg
# >1346051107_9cdc14e070.jpg
# >1346529555_e916816cfe.jpg
# >134724228_30408cd77f.jpg
# >1347519824_e402241e4f.jpg
# >1348113612_5bfc5f429e.jpg
# >1348304997_afe60a61df.jpg
# >1348891916_ebd4413033.jpg
# >134894450_dadea45d65.jpg
# >1348947380_14f0fc1237.jpg
# >1348957576_c4a78eb974.jpg
# >1350811702_2ce7cfd0c5.jpg
# >1350948838_fdebe4ff65.jpg
# >1351315701_6580b51c41.jpg
# >1351764581_4d4fb1b40f.jpg
# >135235570_5698072cd4.jpg
# >1352398363_9cc8ffcce9.jpg
# >1352410176_af6b139734.jpg
# >1354318519_2f9baed754.jpg
# >1355450069_c0675b0706.jpg
# >1355703632_5683a4b6fb.jpg
# >1355833561_9c43073eda.jpg
# >1355935187_2c99648138.jpg
# >1355945307_f9e01a9a05.jpg
# >1356543628_c13ebe38fb.jpg
# >1356796100_b265479721.jpg
# >1357689954_72588dfdc4.jpg
# >1357724865_4faf4e1418.jpg
# >1357753846_6185e26040.jpg
# >1358089136_976e3d2e30.jpg
# >1358892595_7a37c45788.jpg
# >1359101233_16c2c150e3.jpg
# >1361420539_e9599c60ae.jpg
# >1362128028_8422d53dc4.jpg
# >1363843090_9425d93064.jpg
# >1363924449_487f0733df.jpg
# >136552115_6dc3e7231c.jpg
# >136639119_6040b00946.jpg
# >136644343_0e2b423829.jpg
# >136644885_f7d2bbf546.jpg
# >1368338041_6b4077ca98.jpg
# >1368383637_614646cc4a.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      22 #extract features from all images
#      23 directory='Images'
# ---> 24 features=extract_features(directory)
#      25 print('Extracted Features: %d'% len(features))
#      26 #save to file
#
# Cell In[2], line 17, in extract_features(directory)
#      15 image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
#      16 image=preprocess_input(image)
# ---> 17 feature = model.predict(image, verbose=0)
#      18 image_id= name.split('.')[0]
#      19 features[image_id]=feature
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:497, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     492 @traceback_utils.filter_traceback
#     493 def predict(
#     494     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     495 ):
#     496     # Create an iterator that yields batches of input data.
# --> 497     epoch_iterator = TFEpochIterator(
#     498         x=x,
#     499         batch_size=batch_size,
#     500         steps_per_epoch=steps,
#     501         shuffle=False,
#     502         distribute_strategy=self.distribute_strategy,
#     503         steps_per_execution=self.steps_per_execution,
#     504     )
#     506     # Container that configures and calls callbacks.
#     507     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:715, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     713 super().__init__(*args, **kwargs)
#     714 self._distribute_strategy = distribute_strategy
# --> 715 dataset = self.data_adapter.get_tf_dataset()
#     716 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     717     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     718         dataset
#     719     )
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:124, in ArrayDataAdapter.get_tf_dataset(self)
#     111 num_full_batches = int(self._num_samples // batch_size)
#     113 # Vectorized version of shuffle.
#     114 # This is a performance improvement over using `from_tensor_slices`.
#     115 # The indices of the data are shuffled and batched, and these indices
#    (...)
#     121 # 4. optimized permutation batching
#     122 # 5. disabled static optimizations
# --> 124 indices_dataset = tf.data.Dataset.range(1)
#     126 def permutation(_):
#     127     # It turns out to be more performant to make a new set of indices
#     128     # rather than reusing the same range Tensor. (presumably because of
#     129     # buffer forwarding.)
#     130     indices = tf.range(num_samples, dtype=tf.int64)
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1022, in DatasetV2.range(*args, **kwargs)
#    1018 # Loaded lazily due to a circular dependency (dataset_ops -> range_op ->
#    1019 # -> dataset_ops).
#    1020 # pylint: disable=g-import-not-at-top,protected-access
#    1021 from tensorflow.python.data.ops import range_op
# -> 1022 return range_op._range(*args, **kwargs)
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\tensorflow\python\data\ops\range_op.py:25, in _range(*args, **kwargs)
#      24 def _range(*args, **kwargs):  # pylint: disable=unused-private-name
# ---> 25   return _RangeDataset(*args, **kwargs)
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\tensorflow\python\data\ops\range_op.py:35, in _RangeDataset.__init__(self, *args, **kwargs)
#      33 self._parse_args(*args, **kwargs)
#      34 self._structure = tensor_spec.TensorSpec([], self._output_type)
# ---> 35 variant_tensor = gen_dataset_ops.range_dataset(
#      36     start=self._start,
#      37     stop=self._stop,
#      38     step=self._step,
#      39     **self._common_args)
#      40 super().__init__(variant_tensor)
#
# File ~\anaconda3\envs\imgcapt\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6304, in range_dataset(start, stop, step, output_types, output_shapes, metadata, replicate_on_split, name)
#    6302 if tld.is_eager:
#    6303   try:
# -> 6304     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6305       _ctx, "RangeDataset", name, start, stop, step, "output_types",
#    6306       output_types, "output_shapes", output_shapes, "metadata", metadata,
#    6307       "replicate_on_split", replicate_on_split)
#    6308     return _result
#    6309   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import string
def load_doc(filename):
    file = open(filename,'r')
    text=file.read()
    file.close()
    return text
def load_description(doc):
    mapping=dict()
    for line in doc.split('\n'):
        tokens = line.split()
        if len(line)<2:
            continue
        image_id,image_desc=tokens[0],tokens[1:]
        image_id=image_id.split('.')[0]
        image_desc=' '.join(image_desc)
        if image_id not in mapping:
            mapping[image_id]=list()
        mapping[image_id].append(image_desc)
    return mapping


def clean_descriptions(descriptions):
    table=str.maketrans('','',string.punctuation)
    for key,desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc=desc_list[i]
            desc=desc.split()
            desc=[word.lower() for word in desc]
            desc =[w.translate(table) for w in desc]
            desc =[word for word in desc if word.isalpha()]
            desc_list[i]=' '.join(desc)

def to_vocabulary(descriptions):
    all_desc=set()
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
    return all_desc


def save_descriptions(descriptions, filename):
    lines=list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + ' '+desc)
    data='\n'.join(lines)
    file=open(filename,'w')
    file.write(data)
    file.close()

filename='captions.txt'
doc=load_doc(filename)
descriptions=load_description(doc)
print('Loaded: %d ' % len(descriptions))
clean_descriptions(descriptions)
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
save_descriptions(descriptions, 'descriptions.txt')
# Out:
# Loaded: 8091
# Vocabulary Size: 8692

# %%
from pickle import load
import string
def load_doc(filename):
    file=open(filename,'r')
    text = file.read()
    file.close()
    return text

def load_set(filename):
    doc = load_doc(filename)
    dataset=list()
    for line in doc.split('\n'):
        if len(line)<1:
            continue
        identifier=line.split('.')[0]
        dataset.append(identifier)
    return set(dataset)

def load_clean_descriptions(filename,dataset):
    doc=load_doc(filename)
    descriptions=dict()
    for line in doc.split('\n'):
        tokens=line.split()
        if len(tokens) < 2:
            continue  # Skip lines that do not have at least an image ID and a description
        image_id, image_desc = tokens[0], tokens[1:]
        if image_id in dataset:
            if image_id not in descriptions:
                descriptions[image_id]=list()
            desc='startseq'+' '.join(image_desc)+'endseq'
            descriptions[image_id].append(desc)
    return descriptions

def load_photo_features(filename,dataset):
    all_features=load(open(filename,'rb'))
    features={k:all_features[k] for k in dataset}
    return features

filename='captions.txt'
train=load_set(filename)
print('Dataset : %d'% len(train))
train_descriptions=load_clean_descriptions('descriptions.txt',train)
print('Descriptions: train=%d'% len(train_descriptions))
train_features=load_photo_features('features.pkl',train)
print('Photos: %d'%len(train_features))
train_descriptions
# Out:
# Dataset : 8091
# Descriptions: train=8091
# Photos: 8091
# {'1000268201_693b08cb0e': ['startseqchild in a pink dress is climbing up a set of stairs in an entry wayendseq',
#   'startseqgirl going into a wooden buildingendseq',
#   'startseqlittle girl climbing into a wooden playhouseendseq',
#   'startseqlittle girl climbing the stairs to her playhouseendseq',
#   'startseqlittle girl in a pink dress going into a wooden cabinendseq'],
#  '1001773457_577c3a7d70': ['startseqblack dog and a spotted dog are fightingendseq',
#   'startseqblack dog and a tricolored dog playing with each other on the roadendseq',
#   'startseqblack dog and a white dog with brown spots are staring at each other in the streetendseq',
#   'startseqdogs of different breeds looking at each other on the roadendseq',
#   'startseqdogs on pavement moving toward each otherendseq'],
#  '1002674143_1b742ab4b8': ['startseqlittle girl covered in paint sits in front of a painted rainbow with her hands in a bowlendseq',
#   'startseqlittle girl is sitting in front of a large painted rainbowendseq',
#   'startseqsmall girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on itendseq',
#   'startseqis a girl with pigtails sitting in front of a rainbow paintingendseq',
#   'startseqgirl with pigtails painting outside in the grassendseq'],
#  '1003163366_44323f5815': ['startseqman lays on a bench while his dog sits by himendseq',
#   'startseqman lays on the bench to which a white dog is also tiedendseq',
#   'startseqman sleeping on a bench outside with a white and black dog sitting next to himendseq',
#   'startseqshirtless man lies on a park bench with his dogendseq',
#   'startseqlaying on bench holding leash of dog sitting on groundendseq'],
#  '1007129816_e794419615': ['startseqman in an orange hat starring at somethingendseq',
#   'startseqman wears an orange hat and glassesendseq',
#   'startseqman with gauges and glasses is wearing a blitz hatendseq',
#   'startseqman with glasses is wearing a beer can crocheted hatendseq',
#   'startseqman with pierced ears is wearing glasses and an orange hatendseq'],
#  '1007320043_627395c3d8': ['startseqchild playing on a rope netendseq',
#   'startseqlittle girl climbing on red ropingendseq',
#   'startseqlittle girl in pink climbs a rope bridge at the parkendseq',
#   'startseqsmall child grips onto the red ropes at the playgroundendseq',
#   'startseqsmall child climbs on a red ropes on a playgroundendseq'],
#  '1009434119_febe49276a': ['startseqblack and white dog is running in a grassy garden surrounded by a white fenceendseq',
#   'startseqblack and white dog is running through the grassendseq',
#   'startseqboston terrier is running in the grassendseq',
#   'startseqboston terrier is running on lush green grass in front of a white fenceendseq',
#   'startseqdog runs on the green grass near a wooden fenceendseq'],
#  '1012212859_01547e3f17': ['startseqdog shakes its head near the shore a red ball next to itendseq',
#   'startseqwhite dog shakes on the edge of a beach with an orange ballendseq',
#   'startseqwith orange ball at feet stands on shore shaking off waterendseq',
#   'startseqdog playing with a red ball on the shore near the waterendseq',
#   'startseqdog with brown ears standing near water with head turned to one sideendseq'],
#  '1015118661_980735411b': ['startseqboy smiles in front of a stony wall in a cityendseq',
#   'startseqlittle boy is standing on the street while a man in overalls is working on a stone wallendseq',
#   'startseqyoung boy runs aross the streetendseq',
#   'startseqyoung child is walking on a stone paved street with a metal pole and a man behind himendseq',
#   'startseqboy in white shirt and blue jeans in front of rock wall with man in overalls behind himendseq'],
#  '1015584366_dfcec3c85a': ['startseqblack dog leaps over a logendseq',
#   'startseqgrey dog is leaping over a fallen treeendseq',
#   'startseqlarge black dog leaps a fallen logendseq',
#   'startseqmottled black and grey dog in a blue collar jumping over a fallen treeendseq',
#   'startseqblack dog jumped the tree stumpendseq'],
#  '101654506_8eb26cfb60': ['startseqbrown and white dog is running through the snowendseq',
#   'startseqdog is running in the snowendseq',
#   'startseqdog running through snowendseq',
#   'startseqwhite and brown dog is running through a snow covered fieldendseq',
#   'startseqwhite and brown dog is running over the surface of the snowendseq'],
#  '101669240_b2d3e7f17b': ['startseqman in a hat is displaying pictures next to a skier in a blue hatendseq',
#   'startseqman skis past another man displaying paintings in the snowendseq',
#   'startseqperson wearing skis looking at framed pictures set up in the snowendseq',
#   'startseqskier looks at framed pictures in the snow next to treesendseq',
#   'startseqon skis looking at artwork for sale in the snowendseq'],
#  '1016887272_03199f49c4': ['startseqcollage of one person climbing a cliffendseq',
#   'startseqgroup of people are rock climbing on a rock climbing wallendseq',
#   'startseqgroup of people climbing a rock while one man belaysendseq',
#   'startseqclimbers are ascending a rock face whilst another man stands holding the ropeendseq',
#   'startseqclimbers in a row are climbing the rock while the man in red watches and holds the lineendseq'],
#  '1019077836_6fc9b15408': ['startseqbrown dog chases the water from a sprinkler on a lawnendseq',
#   'startseqbrown dog plays with the hoseendseq',
#   'startseqbrown dog running on a lawn near a garden hoseendseq',
#   'startseqdog is playing with a hoseendseq',
#   'startseqbrown dog running away from the sprinkler in the grassendseq'],
#  '1019604187_d087bf9a5f': ['startseqdog prepares to catch a thrown object in a field with nearby carsendseq',
#   'startseqwhite dog is about to catch a yellow ball in its mouthendseq',
#   'startseqwhite dog is about to catch a yellow dog toyendseq',
#   'startseqwhite dog is ready to catch a yellow ball flying through the airendseq',
#   'startseqwhite dog running after a yellow ballendseq'],
#  '1020651753_06077ec457': ['startseqblack and white dog jumping in the air to get a toyendseq',
#   'startseqblack and white dog jumps up towards a yellow toyendseq',
#   'startseqdog leaps to catch a ball in a fieldendseq',
#   'startseqwhite dog is trying to catch a ball in midair over a grassy fieldendseq',
#   'startseqwhite dog is playing in a green field with a yellow toyendseq'],
#  '1022454332_6af2c1449a': ['startseqchild and a woman are at waters edge in a big cityendseq',
#   'startseqlarge lake with a lone duck swimming in it with several people around the edge of itendseq',
#   'startseqlittle boy at a lake watching a duckendseq',
#   'startseqyoung boy waves his hand at the duck in the water surrounded by a green parkendseq',
#   'startseqpeople are at the edge of a lake facing the water and the city skylineendseq'],
#  '1022454428_b6b660a67b': ['startseqcouple and an infant being held by the male sitting next to a pond with a near by strollerendseq',
#   'startseqcouple sit on the grass with a baby and strollerendseq',
#   'startseqcouple with their newborn baby sitting under a tree facing a lakeendseq',
#   'startseqman and woman care for an infant along the side of a body of waterendseq',
#   'startseqwith a baby sit outdoors next to their strollerendseq'],
#  '1022975728_75515238d8': ['startseqblack dog running in the surfendseq',
#   'startseqblack lab with tags frolicks in the waterendseq',
#   'startseqdog splashes in the waterendseq',
#   'startseqblack dog runs through the waterendseq',
#   'startseqis a black dog splashing in the waterendseq'],
#  '102351840_323e3de834': ['startseqman drilling a hole in the iceendseq',
#   'startseqman is drilling through the frozen ice of a pondendseq',
#   'startseqperson in the snow drilling a hole in the iceendseq',
#   'startseqperson standing on a frozen lakeendseq',
#   'startseqmen are ice fishingendseq'],
#  '1024138940_f1fefbdce1': ['startseqdifferent breeds of brown and white dogs play on the beachendseq',
#   'startseqdogs are making a turn on a soft sand beachendseq',
#   'startseqdogs playing in the sand at the beachendseq',
#   'startseqdogs playing together on a beachendseq',
#   'startseqlarge tan dogs play along a sandy beachendseq'],
#  '102455176_5f8ead62d5': ['startseqman uses ice picks and crampons to scale iceendseq',
#   'startseqice climber in a blue jacket and black pants is scaling a frozen ice wallendseq',
#   'startseqice climber scaling a frozen waterfallendseq',
#   'startseqperson in blue and red ice climbing with two picksendseq',
#   'startseqclimbing an ice wallendseq'],
#  '1026685415_0431cbf574': ['startseqblack dog carries a green toy in his mouth as he walks through the grassendseq',
#   'startseqblack dog carrying something through the grassendseq',
#   'startseqblack dog has a blue toy in its mouthendseq',
#   'startseqdog in grass with a blue item in his mouthendseq',
#   'startseqwet black dog is carrying a green toy through the grassendseq'],
#  '1028205764_7e8df9a2ea': ['startseqman and a baby are in a yellow kayak on waterendseq',
#   'startseqman and a little boy in blue life jackets are rowing a yellow canoeendseq',
#   'startseqman and child kayak through gentle watersendseq',
#   'startseqman and young boy ride in a yellow kayakendseq',
#   'startseqand child in yellow kayakendseq'],
#  '1030985833_b0902ea560': ['startseqblack dog and a brown dog are jumping up to catch a red toyendseq',
#   'startseqblack dog and a brown dog play with a red toy on a courtyardendseq',
#   'startseqbrown and black lab are outside and the black lab is catching a toy in its mouthendseq',
#   'startseqdog snaps at red and black object as brown dog lungesendseq',
#   'startseqchocolate lab jumps too late to get the toy as the black lab captures it in the drivewayendseq'],
#  '103106960_e8a41d64f8': ['startseqboy with a stick kneeling in front of a goalie netendseq',
#   'startseqchild in a red jacket playing street hockey guarding a goalendseq',
#   'startseqyoung kid playing the goalie in a hockey rinkendseq',
#   'startseqyoung male kneeling in front of a hockey goal with a hockey stick in his right handendseq',
#   'startseqgoalie boy in red jacket crouches by goal with stickendseq'],
#  '103195344_5d2dc613a3': ['startseqman in black is sitting next to a modern art structure in front of a glass buildingendseq',
#   'startseqman sits and reads a newspaper by a sculpture outside of an office buildingendseq',
#   'startseqman sits near a large statueendseq',
#   'startseqman sitting in front of a metal sculpture in front of a buildingendseq',
#   'startseqman with the backpack is sitting in a buildings courtyard in front of an art sculpture readingendseq'],
#  '103205630_682ca7285b': ['startseqtent is being set up on the iceendseq',
#   'startseqmen are about to enter an ice fishing tent on a snow covered lakeendseq',
#   'startseqmen setting up a blue ice fishing hut on an iced over lakeendseq',
#   'startseqmen standing on an ice looking into something covered with a blue tarpendseq',
#   'startseqpeople standing outside a blue tent structure on a snowy surfaceendseq'],
#  '1032122270_ea6f0beedb': ['startseqwoman crouches near three dogs in a fieldendseq',
#   'startseqdogs are playing on grassy hill with a blue skyendseq',
#   'startseqdogs are standing in the grass and a person is sitting next to themendseq',
#   'startseqdogs on a grassy hillendseq',
#   'startseqdogs stand in a grassy field while a person kneels nearbyendseq'],
#  '1032460886_4a598ed535': ['startseqman is standing in front of a skyscraperendseq',
#   'startseqman stands in front of a skyscraperendseq',
#   'startseqman stands in front of a very tall buildingendseq',
#   'startseqthe man in a red shirt stands a large skyscraperendseq',
#   'startseqis a skyscraper in the distance with a man walking in front of the cameraendseq'],
#  '1034276567_49bb87c51c': ['startseqboy bites hard into a treat while he sits outsideendseq',
#   'startseqchild biting into a baked goodendseq',
#   'startseqsmall boy putting something in his mouth with both handsendseq',
#   'startseqboy eats his food outside at the tableendseq',
#   'startseqboy is eating pizza over a tin dishendseq'],
#  '104136873_5b5d41be75': ['startseqsit on the mountainside and check out the viewendseq',
#   'startseqpeople are on a hilltop overlooking a green valleyendseq',
#   'startseqpeople hang out on top of a big hillendseq',
#   'startseqpeople overlook a green valleyendseq',
#   'startseqpeople rest on a ledge above the moutainsendseq'],
#  '1042020065_fb3d3ba5ba': ['startseqboy in a green shirt is looking down at many inflatable boatsendseq',
#   'startseqboy in a green shirt watches kayakersendseq',
#   'startseqboy looks over a railing at the many boats and rafts below in the waterendseq',
#   'startseqyoung boy overlooking a crowd of inflatable boatsendseq',
#   'startseqyoung boy wearing a jersey looks down over a ledge at many boats in the waterendseq'],
#  '1042590306_95dea0916c': ['startseqman and woman pose for the camera while another man looks onendseq',
#   'startseqman is holding the hand of a woman up to his mouth in front of some buildings while another man looks onendseq',
#   'startseqmultiracial couple posing for a pictureendseq',
#   'startseqman and blond woman holding hands outdoors man in background watchesendseq',
#   'startseqin blue shirt biting hand of girl in black striped jacket while another guy watchesendseq'],
#  '1045521051_108ebc19be': ['startseqperson eats takeout while watching a small televisionendseq',
#   'startseqperson sits on the floor and eats in front of a televisionendseq',
#   'startseqtelevision with a picture of a girl on itendseq',
#   'startseqyoung man sits on the floor by the television with a fast food meal in front of himendseq',
#   'startseqis laying in front of the tv eating foodendseq'],
#  '1048710776_bb5b0a5c7c': ['startseqcouple of several people sitting on a ledge overlooking the beachendseq',
#   'startseqgroup of people sit on a wall at the beachendseq',
#   'startseqgroup of teens sit on a wall by a beachendseq',
#   'startseqof people at the beachendseq',
#   'startseqyoung people sitting on a rail above a crowded beachendseq'],
#  '1052358063_eae6744153': ['startseqboy takes a jump on his skateboard while another boy with a skateboard watchesendseq',
#   'startseqchild is performing a skateboard trick while another child with a skateboard leans on a wallendseq',
#   'startseqlittle boy skateboarder is doing a trick on his board while another young skateboarder watchesendseq',
#   'startseqyoung boy skateboarder jumping on a platform on a skateboardendseq',
#   'startseqskateboardersendseq'],
#  '105342180_4d4a40b47f': ['startseqgirl paddling down a large river as seen from behind herendseq',
#   'startseqwoman kayaking down a riverendseq',
#   'startseqwoman paddles a boat down a riverendseq',
#   'startseqwoman with a paddleendseq',
#   'startseqwoman with a paddle sits in a boat on the waterendseq'],
#  '1053804096_ad278b25f1': ['startseqgirl in pigtails splashes in the shallow waterendseq',
#   'startseqgirls plays in the surfendseq',
#   'startseqgirl with pigtails is playing in the ocean by the beachendseq',
#   'startseqgirl with pigtails plays in the waterendseq',
#   'startseqyoung girl in pigtails plays in the waterendseq'],
#  '1055623002_8195a43714': ['startseqgroup of four children wearing pajamas have a pillow fightendseq',
#   'startseqgroup of kids have a pillowfightendseq',
#   'startseqgroup of young children playing pillow fight on a bedendseq',
#   'startseqhaving a pillow fightendseq',
#   'startseqchildren are having a pillow fightendseq'],
#  '1055753357_4fa3d8d693': ['startseqconstructions workers sit on a beam taking a breakendseq',
#   'startseqconstruction workers are sitting up on the side of a buildingendseq',
#   'startseqconstruction workers sitting on an ibeamendseq',
#   'startseqconstruction workers take a seat on a steel beamendseq',
#   'startseqmen take a break from constructionendseq'],
#  '1056249424_ef2a2e041c': ['startseqchildren are playing in the waterendseq',
#   'startseqboys one with a yellow and orange ball play in some water in front of a fieldendseq',
#   'startseqboys play in a puddleendseq',
#   'startseqchildren play with a balloon in mud on a sunny dayendseq',
#   'startseqkids are running and playing in some waterendseq'],
#  '1056338697_4f7d7ce270': ['startseqblond woman in a blue shirt appears to wait for a rideendseq',
#   'startseqblond woman is on the street hailing a taxiendseq',
#   'startseqwoman is signaling is to traffic as seen from behindendseq',
#   'startseqwoman with blonde hair wearing a blue tube top is waving on the side of the streetendseq',
#   'startseqwoman in the blue dress is holding out her arm at oncoming trafficendseq'],
#  '1056359656_662cee0814': ['startseqlittle girl looking at a brochure on train ridesendseq',
#   'startseqyoung blond girl with a magizine in her handsendseq',
#   'startseqyoung girl on a train reads a book about train ridesendseq',
#   'startseqyoung girl sits on a seat and looks at a train pamphletendseq',
#   'startseqsitting down looking at train ride brochureendseq'],
#  '1056873310_49c665eb22': ['startseqbrown dog is running after a black dog on a rocky shoreendseq',
#   'startseqbrown dog is running after the black dogendseq',
#   'startseqdogs playing on a beachendseq',
#   'startseqdogs run across stones near a body of waterendseq',
#   'startseqdogs run towards each other on a rocky area with water in the backgroundendseq'],
#  '1057089366_ca83da0877': ['startseqboy descends off the end of a high diving boardendseq',
#   'startseqchild jumps off a high diving board into the poolendseq',
#   'startseqkid jumps off the diving board and into the swimming pool belowendseq',
#   'startseqlittle kid is jumping off a high dive at the poolendseq',
#   'startseqboy is jumping off a high diving board into the poolendseq'],
#  '1057210460_09c6f4c6c1': ['startseqguy stands by a window taking his overshirt offendseq',
#   'startseqman in a tank top stands next to a chrome doorendseq',
#   'startseqman puts his shirt on near an elevatorendseq',
#   'startseqman stands by an elevator with his head downendseq',
#   'startseqman is putting on his shirt near an elevatorendseq'],
#  '1057251835_6ded4ada9c': ['startseqlightcolored dog runs on the beachendseq',
#   'startseqsmall yellow dog runs on a beachendseq',
#   'startseqtan dog runs on a sandy beachendseq',
#   'startseqwhite dog is running down a rocky beachendseq',
#   'startseqbrown dog running along the beachendseq'],
#  '106490881_5a2dd9b7bd': ['startseqboy in his blue swim shorts at the beachendseq',
#   'startseqboy smiles for the camera at a beachendseq',
#   'startseqyoung boy in swimming trunks is walking with his arms outstretched on the beachendseq',
#   'startseqplaying on the beachendseq',
#   'startseqboy is playing on the shore of an oceanendseq'],
#  '106514190_bae200f463': ['startseqhiker standing high on a bluff overlooking the mountains belowendseq',
#   'startseqperson on ski s looks from hill over snow covered landscapeendseq',
#   'startseqskier is overlooking a snowcovered mountainendseq',
#   'startseqskier is overlooking the beautiful white snow covered landscapeendseq',
#   'startseqskier pauses on a mountaintopendseq'],
#  '1067180831_a59dc64344': ['startseqblack and white dog is attempting to catch a yellow and purple object in a low cut yardendseq',
#   'startseqblack and white dog jumps after a yellow toyendseq',
#   'startseqblack and white dog jumps to get the frisbeeendseq',
#   'startseqblack dog is jumping up to catch a purple and green toyendseq',
#   'startseqdog jumps to catch a toyendseq'],
#  '1067675215_7336a694d6': ['startseqman in blue shorts is laying in the streetendseq',
#   'startseqman in blue shorts lays down outside in a parking lotendseq',
#   'startseqman laying down in middle of street during heavy trafficendseq',
#   'startseqman lies on a mat in a parking lot between a brown suv and a yellow pickup with an open doorendseq',
#   'startseqshirtless man is laying down in the middle of a busy streetendseq'],
#  '1067790824_f3cc97239b': ['startseqwhite and black dog and a brown dog in sandy terrainendseq',
#   'startseqwoolly dog chases a doberman on a beachendseq',
#   'startseqdog is chasing another one on the beachendseq',
#   'startseqtwo large dogs are running through sandendseq',
#   'startseqlarge dogs chasing each other at the beachendseq'],
#  '1072153132_53d2bb1b60': ['startseqblack and white dog catches a toy in midairendseq',
#   'startseqdog and a tennis ballendseq',
#   'startseqdog is jumping to catch a object thrown at itendseq',
#   'startseqdog leaps while chasing a tennis ball through a grassy fieldendseq',
#   'startseqmulticolor dog jumping to catch a tennis ball in a grassy fieldendseq'],
#  '107318069_e9f2ef32de': ['startseqcrowd watching air balloons at nightendseq',
#   'startseqgroup of hot air balloons lit up at nightendseq',
#   'startseqare watching hot air balloons in the parkendseq',
#   'startseqwatching hot air balloonsendseq',
#   'startseqlarge balloons are lined up at nighttime near a crowdendseq'],
#  '1075716537_62105738b4': ['startseqchild with a helmet on his head rides a bikeendseq',
#   'startseqlittle boy rides a bike down a hill on a miniature dirt bikeendseq',
#   'startseqyoung boy in a helmet rides a bike on the roadendseq',
#   'startseqlittle boy rides his bicycle in a raceendseq',
#   'startseqyoung boy pedals quickly at a bmx raceendseq'],
#  '107582366_d86f2d3347': ['startseqgroup of eight people are gathered around a table at nightendseq',
#   'startseqgroup of people gathered around in the darkendseq',
#   'startseqgroup of people sit around a table outside on a porch at nightendseq',
#   'startseqgroup of people sit outdoors together at nightendseq',
#   'startseqgroup of people sitting at a table in a darkened roomendseq'],
#  '1075867198_27ca2e7efe': ['startseqman in a brown shirt and dark shorts plays on the beach with his two black dogsendseq',
#   'startseqman in shorts with two black dogs holds a ball throwing toy at the beachendseq',
#   'startseqman playing with two black dogs on the beachendseq',
#   'startseqman with two dogs on a beachendseq',
#   'startseqat the beach with two dogsendseq'],
#  '1075881101_d55c46bece': ['startseqboy cleans the bubbles off his faceendseq',
#   'startseqboy covered in suds has his face wiped cleanendseq',
#   'startseqboy is covered in bubblesendseq',
#   'startseqchild covered in foam is climbing on a black inflatable rampendseq',
#   'startseqperson covered in soapy water is getting cleaned offendseq'],
#  '1077546505_a4f6c4daa9': ['startseqboy in blue shorts slides down a slide into a poolendseq',
#   'startseqboy in blue swimming trunks slides down a yellow slide into a wading pool with inflatable toys floating in the waterendseq',
#   'startseqboy rides down a slide into a small backyard poolendseq',
#   'startseqboy sliding down a slide into a pool with colorful tubesendseq',
#   'startseqchild is falling off a slide onto colored balloons floating on a pool of waterendseq'],
#  '1077931201_1e0bb83105': ['startseqman in a wetsuit is throwing a baby wearing a wetsuit up into the airendseq',
#   'startseqman in a wetsuit is throwing a toddler up in the air and is ready to catch himendseq',
#   'startseqman in water throwing a little boy up in the air and waiting for him to come down so he can catch himendseq',
#   'startseqman is in the pool and throwing a small boy into the airendseq',
#   'startseqwater droplets fly a man throws a little boy up in the airendseq'],
#  '1079274291_9aaf896cc1': ['startseqlittle boy sticks his tongue out for the camera another boy looks onendseq',
#   'startseqboys make facesendseq',
#   'startseqyoung boys are looking at the camera one smiling the other sticking his tongue outendseq',
#   'startseqyoung boys look up at the camera as one sticks out his tongueendseq',
#   'startseqyoung boys making silly facesendseq'],
#  '10815824_2997e03d76': ['startseqblonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrelendseq',
#   'startseqgirl and her horse stand by a fireendseq',
#   'startseqgirl holding a horse s lead behind a fireendseq',
#   'startseqman and girl and two horses are near a contained fireendseq',
#   'startseqpeople and two horses watching a fireendseq'],
#  '1082252566_8c79beef93': ['startseqbulldog a sheep dog and a boxer standing in a yardendseq',
#   'startseqlarge brown dog is pushing a small boston terrier with his face while anouther dog watchesendseq',
#   'startseqlarge skinny dog stands near two smaller dogs int the dirtendseq',
#   'startseqare three dogs starring at a ball in the middle of themendseq',
#   'startseqdogs of various sizesendseq'],
#  '1082379191_ec1e53f996': ['startseqlady and a man with no shirt sit on a dockendseq',
#   'startseqman and a woman are sitting on a dock togetherendseq',
#   'startseqman and a woman sitting on a dockendseq',
#   'startseqman and woman sitting on a deck next to a lakeendseq',
#   'startseqshirtless man and a woman sitting on a dockendseq'],
#  '1084040636_97d9633581': ['startseqcloseup of a white dog that is laying its head on its pawsendseq',
#   'startseqlarge white dog lying on the floorendseq',
#   'startseqwhite dog has its head on the groundendseq',
#   'startseqwhite dog is resting its head on a tiled floor with its eyes openendseq',
#   'startseqwhite dog rests its head on the patio bricksendseq'],
#  '1084104085_3b06223afe': ['startseqwoman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harnessendseq',
#   'startseqwoman in blue shorts and a white shirt is indoor rock climbingendseq',
#   'startseqgirl is climbing a rock wallendseq',
#   'startseqgirl is in a harness climbing rocksendseq',
#   'startseqclimbing an artificial rock wallendseq'],
#  '1087168168_70280d024a': ['startseqboy is jumping on an inflatable ring and a girl is watching himendseq',
#   'startseqboy jumping on a water jumphouseendseq',
#   'startseqteenage boy is jumping on an inflatable slideendseq',
#   'startseqyoung boy jumping and a young girl seating in an inflatable poolendseq',
#   'startseqyoung kids are playing in the water on an inflated toyendseq'],
#  '1087539207_9f77ab3aaf': ['startseqfamily playing on a tractor on a beautiful dayendseq',
#   'startseqride a tractor in a fieldendseq',
#   'startseqchildren playing on a polaris vehicle outdoorsendseq',
#   'startseqchildren played on the four wheeler in the fieldendseq',
#   'startseqfour kids are riding on an atv in a fieldendseq'],
#  '1088767354_2acee738cf': ['startseqwoman in a red costume to the left of a man and woman standing togetherendseq',
#   'startseqwoman wearing a red costume looks at two other people standing on a streetendseq',
#   'startseqyoung woman in a red sequined costume and feather stands on the sidewalkendseq',
#   'startseqgirl in the salmon colored bikini is standing next to two young people one is wearing a black outfit and the other is drinking popendseq',
#   'startseqyoung people are approached by a flamboyant young woman dressed in a red bikini and a red feathered headressendseq'],
#  '108898978_7713be88fc': ['startseqwalking up the hill through a forestendseq',
#   'startseqmen are skiing in the snow in a wooded areaendseq',
#   'startseqpeople wearing yellow jackets crosscountry skiingendseq',
#   'startseqskiers are making their way through woodlandendseq',
#   'startseqskiers are sliding down a trail in the woodsendseq'],
#  '108899015_bf36131a57': ['startseqlone skier is making their way up a mountainendseq',
#   'startseqat the top of a snow covered hillendseq',
#   'startseqhikers climbing a snowy hillendseq',
#   'startseqpeople are on a snowcovered mountainendseq',
#   'startseqpeople climbing up a snowy mountainendseq'],
#  '1089181217_ee1167f7af': ['startseqbrown dog running down a paved pathwayendseq',
#   'startseqbrown dog running next to grassendseq',
#   'startseqdog is running down a roadendseq',
#   'startseqlight brown dog runs down a path happilyendseq',
#   'startseqbrown dog runningendseq'],
#  '1089755335_0bfbfd30e6': ['startseqmother and children is fishing on a boardwalk at nightendseq',
#   'startseqwoman and three children stand on a deck with a fishing poleendseq',
#   'startseqwoman stands with children on a boardwalk at night overlooking the seaendseq',
#   'startseqpeople on a pier at night with one girl fishing off itendseq',
#   'startseqwith three children fishing over boardwalk in the eveningendseq'],
#  '109202756_b97fcdc62c': ['startseqwoman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snowcovered mountainendseq',
#   'startseqwoman in a blue jacket rides a brown pony near waterendseq',
#   'startseqwoman rides a horse near a frozen lake in the wintertimeendseq',
#   'startseqyoung blond woman sitting atop a brown draft horse in the snowy mountainsendseq',
#   'startseqn blue jacket sits on daft horse near a frozen lakeendseq'],
#  '109202801_c6381eef15': ['startseqdraft horses pull a cart through the snowendseq',
#   'startseqgolden brown horses pull a sleigh driven by a woman in a blue coatendseq',
#   'startseqhorses are pulling a woman in a cartendseq',
#   'startseqhorses pull a carriage driven by a woman over snow covered groundendseq',
#   'startseqhorses pulling a sled steered by a smiling blond womanendseq'],
#  '109260216_85b0be5378': ['startseqperson climbing down a sheer rock cliff using a ropeendseq',
#   'startseqperson climbs a tall flat mountain while holding onto a safety ropeendseq',
#   'startseqperson is climbing a rock while holding onto a white ropeendseq',
#   'startseqperson rappels down a steep inclineendseq',
#   'startseqperson wearing a red vest climbs up a steep rockendseq'],
#  '109260218_fca831f933': ['startseqstand inside a rock domeendseq',
#   'startseqof light in a cave shows three spelunkersendseq',
#   'startseqpose inside a rock cavern while bathed in sunlight from the surfaceendseq',
#   'startseqpeople sit in a caveendseq',
#   'startseqrock climbers are posing on big rocksendseq'],
#  '1093716555_801aacef79': ['startseqgroup of backpackers lay on the dry groundendseq',
#   'startseqgroup of hikers are resting on the ground in front of some mountainsendseq',
#   'startseqcamp with the mountains in the backgroundendseq',
#   'startseqhikers rest with their gear in front of a mountainendseq',
#   'startseqgroup of hikers is resting in front of a mountainendseq'],
#  '1093737381_b313cd49ff': ['startseqwoman in a blue dress stands with a chalk portrait of two children playing by a streamendseq',
#   'startseqwoman standing in front of a chalk drawingendseq',
#   'startseqwoman stands next to a chalk drawing in front of a barnlike structureendseq',
#   'startseqwoman stands outside near an elaborate chalk illustrationendseq',
#   'startseqwoman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalkendseq'],
#  '1094462889_f9966dafa6': ['startseqbrown dog plays in a deep pile of snowendseq',
#   'startseqdog looking at the camera in snowendseq',
#   'startseqdog runs through the snowendseq',
#   'startseqtan dog stand in the snow and looks upendseq',
#   'startseqbrown dog is out in the snowendseq'],
#  '1095476286_87d4f8664e': ['startseqboy jumping in a fountainendseq',
#   'startseqboy plays in the fountainsendseq',
#   'startseqchild plays in a fountainendseq',
#   'startseqlittle boy playing in the waterendseq',
#   'startseqyoung boy is jumping through water being sprayed up from the groundendseq'],
#  '1095580424_76f0aa8a3e': ['startseqcorgi runs out of a tunnelendseq',
#   'startseqdog runs out of a tunnel on a courseendseq',
#   'startseqrunning out of tunnel on obstacle courseendseq',
#   'startseqdog is running out of the tunnel on a dog obedience courseendseq',
#   'startseqsmall brown and white dog is running out of a small tunnelendseq'],
#  '1095590286_c654f7e5a9': ['startseqblond dog and a black and white dog run in a dirt fieldendseq',
#   'startseqdog chases another dogendseq',
#   'startseqyellow dog and a black and white dog are running in the dirtendseq',
#   'startseqdogs are running in a fieldendseq',
#   'startseqdogs running aroundendseq'],
#  '1095980313_3c94799968': ['startseqlittle girl in a blue swimsuit is walking along a wooden fence next to a sandy beachendseq',
#   'startseqlittle girl with arms outstretched is posing at the beachendseq',
#   'startseqyoung girl walks on a railing in front of the beachendseq',
#   'startseqgirl in blue swimsuit standing on a handrail near a beachendseq',
#   'startseqlittle girl in the blue bathing suit is posing at the beachendseq'],
#  '1096097967_ac305887b4': ['startseqblack and white dog drinking water from a water sprayendseq',
#   'startseqblack and white dog is being soaked with a jet of water in a blue paddling poolendseq',
#   'startseqdog sticking its face into the shower from a garden hoseendseq',
#   'startseqsmall white dog gets sprayed by waterendseq',
#   'startseqwhite and black dog is jumping into a poolendseq'],
#  '1096165011_cc5eb16aa6': ['startseqboy smiles underwaterendseq',
#   'startseqredheaded boy swimming underwaterendseq',
#   'startseqsmall boy swimming underwaterendseq',
#   'startseqsmiling boy swims underwater in a poolendseq',
#   'startseqboys smiles underwater at the poolendseq'],
#  '1096395242_fc69f0ae5a': ['startseqboy with a toy gunendseq',
#   'startseqlittle boy in orange shorts playing with a toyendseq',
#   'startseqyoung boy with his foot outstretched aims a toy at the camera in front of a fireplaceendseq',
#   'startseqyoung child plays with his new lightup toyendseq',
#   'startseqwith toy gun pointed at the cameraendseq'],
#  '109671650_f7bbc297fa': ['startseqboy in yellow shorts is standing on top of a cliffendseq',
#   'startseqboy wearing blue and yellow walking on a cliff edgeendseq',
#   'startseqlittle boy standing high in the air on a rockendseq',
#   'startseqyoung child is standing alone on some jagged rocksendseq',
#   'startseqstands near edge of cliffendseq'],
#  '109738763_90541ef30d': ['startseqperson on a snowmobile in mid jumpendseq',
#   'startseqsnowmobiler flies through the airendseq',
#   'startseqsnowmobile rider flies through the air on his or her machine in front of tall pine treesendseq',
#   'startseqjumps snowmobile high in rural areaendseq',
#   'startseqman is up in the airendseq'],
#  '109738916_236dc456ac': ['startseqare riding around on snowmobilesendseq',
#   'startseqpose with helmets and goggles on while riding snowmobilesendseq',
#   'startseqpeople are taking a break while on a snowmobiling rideendseq',
#   'startseqpeople and two snowmobilesendseq',
#   'startseqhelmeted men sit on yellow snowmobiles while another man stands behind watchingendseq'],
#  '109823394_83fcb735e1': ['startseqpeople drive atvsendseq',
#   'startseqpeople on atvs in a brown field turn their heads to look at the cameraendseq',
#   'startseqpeople on atv s outsideendseq',
#   'startseqpeople on four wheel atv s in a fieldendseq',
#   'startseqpeople ride their four wheelers through the fieldendseq'],
#  '109823395_6fb423a90f': ['startseqfour wheeler jumping in an empty fieldendseq',
#   'startseqman on a four wheeler is flying through the airendseq',
#   'startseqperson is riding an orange atv in a large empty fieldendseq',
#   'startseqjumping with all terrain vehicleendseq',
#   'startseqon an atv catching airendseq'],
#  '109823397_e35154645f': ['startseqman jumps gin the air while riding an atvendseq',
#   'startseqman on a fourwheeler jumps near a small buildingendseq',
#   'startseqatv is airborne over a field in front of a white structureendseq',
#   'startseqperson dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out buildingendseq',
#   'startseqon four wheeler in the airendseq'],
#  '1100214449_d10861e633': ['startseqboy in s striped shirt is jumping in front of a water fountainendseq',
#   'startseqboy is jumping off the side of a running stone water fountain in front of a buildingendseq',
#   'startseqhappy boy is jumping in front od city fountainendseq',
#   'startseqlittle boy is jumping in front of a fountainendseq',
#   'startseqlittle boy is playfully jumping off the side of a fountainendseq'],
#  '1104133405_c04a00707f': ['startseqboy carrying a soccer ballendseq',
#   'startseqboy walks with a ball tucked under his armendseq',
#   'startseqboy walks with a soccer ball near a fenceendseq',
#   'startseqboy wearing a white tshirt walks on the grass and carries a soccer ballendseq',
#   'startseqboy carries a soccer ball on a fieldendseq'],
#  '1105959054_9c3a738096': ['startseqchild painting a pictureendseq',
#   'startseqartist paints clouds onto a canvasendseq',
#   'startseqyoung girl painting a pictureendseq',
#   'startseqyoung girl with braids is painting with water colors on a white paper on the wallendseq',
#   'startseqchild paints on a large paper with water colorsendseq'],
#  '110595925_f3395c8bd6': ['startseqcyclist is riding a bicycle on a curved road up a hillendseq',
#   'startseqman in aerodynamic gear riding a bicycle down a road around a sharp curveendseq',
#   'startseqman on a mountain bike is pedaling up a hillendseq',
#   'startseqbicycle up a road while cows graze on a hill nearbyendseq',
#   'startseqbiker is riding around a curve in the roadendseq'],
#  '1107246521_d16a476380': ['startseqblack dog jumping to catch a rope toyendseq',
#   'startseqblack dog playing fetch with a ball of ropeendseq',
#   'startseqblack dog pounces to get a rope toyendseq',
#   'startseqblack dog running after his rope toyendseq',
#   'startseqlarge black dog is playing in a grassy yardendseq'],
#  '1107471216_4336c9b328': ['startseqlittle girl is holding a cine camera in front of her faceendseq',
#   'startseqyoung girl is looking through an old fashioned video cameraendseq',
#   'startseqyoung girl steadies her aim with a cameraendseq',
#   'startseqwith rosy cheeks and lips holding black toy gunendseq',
#   'startseqis a kid with a gunendseq'],
#  '1110208841_5bb6806afe': ['startseqblack and white border collie catches a frisbee in front of an audienceendseq',
#   'startseqbrown and white dog catches a frisbee in it mouth in front of a group of peopleendseq',
#   'startseqbrown and white dug jumping up to catch a frisbee while an audience watchesendseq',
#   'startseqdog jumps to catch a frisbee while many people watchendseq',
#   'startseqagile dog catches a frisbee while a crowd of onlookers watches closelyendseq'],
#  '1112212364_0c48235fc2': ['startseqbaby is sitting on and playing with smooth rocksendseq',
#   'startseqbaby is stacking rocks on the beachendseq',
#   'startseqsmall boy is playing with rocksendseq',
#   'startseqtoddler sitting on a pile of rocks holding a rock at a beachendseq',
#   'startseqsits on a pile of rocksendseq'],
#  '111497985_38e9f88856': ['startseqkid rock climbing against the backdrop of a green valleyendseq',
#   'startseqwoman in a striped shirt climbs up a mountainendseq',
#   'startseqyoung man climbs a rocky hillendseq',
#   'startseqperson has a striped shirt on and is holding on to a rope on a mountainendseq',
#   'startseqperson in the striped shirt is mountain climbingendseq'],
#  '111537217_082a4ba060': ['startseqman climbing a rock wallendseq',
#   'startseqman climbing the side of a cliffendseq',
#   'startseqman is rock climbingendseq',
#   'startseqwith red shoes white shirt and grey pants climbingendseq',
#   'startseqyoung man with the white tshirt and jeans is rappeling up the rock wallendseq'],
#  '111537222_07e56d5a30': ['startseqclimber wearing a blue helmet and headlamp is attached to a rope on the rock faceendseq',
#   'startseqman climbs a rocky wallendseq',
#   'startseqrock climber climbs a large rockendseq',
#   'startseqwoman in purple snakeskin pants climbs a rockendseq',
#   'startseqwith blue helmet and purple pants is rock climbingendseq'],
#  '1115565519_d976d4b1f1': ['startseqchild playing with a fountain at the beachendseq',
#   'startseqchild plays with a fountainendseq',
#   'startseqgirl looks at a fountain that sprays waterendseq',
#   'startseqlittle girl playing in water on a frog sculptureendseq',
#   'startseqlittle girl is playing with a toy in a public fountainendseq'],
#  '1115679311_245eff2f4b': ['startseqblack dog is jumping over a log along a beachendseq',
#   'startseqblack dog runs along the beach and jumps over a wood barriorendseq',
#   'startseqdog is running on the beachendseq',
#   'startseqdog jumping over a small wall at a beach near the waterendseq',
#   'startseqanimal is running on the beachendseq'],
#  '111766423_4522d36e56': ['startseqblack and white bird eating seeds out of someone s handendseq',
#   'startseqblack and white bird standing on a handendseq',
#   'startseqsmall bird sits in a person s hand and eats seedsendseq',
#   'startseqand white bird standing on hand of someone holding sunflower seedsendseq',
#   'startseqsmall bird is clinging to a finger of the hand holding the seedsendseq'],
#  '1117972841_2b9261f95f': ['startseqbrown dog is running in the sandendseq',
#   'startseqbrown dog playing in the sandendseq',
#   'startseqbrown dog plays at the beachendseq',
#   'startseqdog is standing in the sandendseq',
#   'startseqdog running fast in the sandendseq'],
#  '1118557877_736f339752': ['startseqlittle boy stands in the surfendseq',
#   'startseqsmall child wades through the water while being guided by another personendseq',
#   'startseqyoung boy laughs while splashing in the oceanendseq',
#   'startseqyoung boy wearing a colorful bathing suit splashing in the oceanendseq',
#   'startseqyoung child splashing in waterendseq'],
#  '1119015538_e8e796281e': ['startseqlittle tan dog with large ears running through the grassendseq',
#   'startseqplayful dog is running through the grassendseq',
#   'startseqsmall dogs ears stick up as it runs in the grassendseq',
#   'startseqsmall dog is running across the lawnendseq',
#   'startseqis a small beige dog running through a grassy fieldendseq'],
#  '1119418776_58e4b93eac': ['startseqblack and white dog is running through the fieldendseq',
#   'startseqblack brown and white dog running through a fieldendseq',
#   'startseqbrown black and white dog is running through a large field with its mouth openendseq',
#   'startseqdog running in a fieldendseq',
#   'startseqdog with its mouth open running through a field torwards the cameraendseq'],
#  '1119463452_69d4eecd08': ['startseqgirl in a pink swimsuit in a poolendseq',
#   'startseqgirl swimming in a poolendseq',
#   'startseqlittle girl in a pink bathing suit swimming in a poolendseq',
#   'startseqlittle girl swimming in a poolendseq',
#   'startseqlittle girl swimming in outdoor poolendseq'],
#  '1121416483_c7902d0d49': ['startseqchild is standing on her headendseq',
#   'startseqlittle girl standing on her headendseq',
#   'startseqsmall child doing a handstand on a bedendseq',
#   'startseqyoung girl does a handstand on a bed with blue sheetsendseq',
#   'startseqgirl is upside down on a bedendseq'],
#  '112178718_87270d9b4d': ['startseqguy stands in the sand with a snowboard behind himendseq',
#   'startseqman holds a surfboard on the beachendseq',
#   'startseqman holds his snowboard in the sandendseq',
#   'startseqman with his surfboard stands in the sandendseq',
#   'startseqis standing on white sand and holding a snowboardendseq'],
#  '112243673_fd68255217': ['startseqon atvs and dirt bikes are traveling along a worn path in a field surrounded by treesendseq',
#   'startseqpeople are riding around on atv s and motorcyclesendseq',
#   'startseqpeople on motorbikes follow a trail through dry grassendseq',
#   'startseqpeople on two dirtbikes and one fourwheeler are riding through brown grassendseq',
#   'startseqpeople ride offroad bikes through a field surrounded by treesendseq'],
#  '1122944218_8eb3607403': ['startseqbaby in a white garment holds a flag with crescent moon and starendseq',
#   'startseqbaby is holding a small black flag with a moon and a star on itendseq',
#   'startseqbaby wearing a white gown waves a muslim flagendseq',
#   'startseqlittle toddler dressed in white is smiling while a lady helps him wave a flagendseq',
#   'startseqin white outfit holding black and white flagendseq'],
#  '1124448967_2221af8dc5': ['startseqhalf naked man is sleeping on his chair outdoorsendseq',
#   'startseqolder man sits back and relaxes on a patio outside an adobe building where many bicycles are proppedendseq',
#   'startseqshirtless man in a white cap relaxes in a deck chair close to three parked bicyclesendseq',
#   'startseqrelaxing in a folding chair on the streetendseq',
#   'startseqold man wearing slippers navy blue pants and a white hat while reclining in a chair outsideendseq'],
#  '1129704496_4a61441f2c': ['startseqbrown and white and a black and white dog hauling in a floating toy from the oceanendseq',
#   'startseqdogs retrieve the play toy from the waterendseq',
#   'startseqdogs in the ocean playing with a toyendseq',
#   'startseqdogs run through the water with a rope in their mouthsendseq',
#   'startseqdogs tug at a chew toy in the surfendseq'],
#  '1130017585_1a219257ac': ['startseqare three young people one dark haired holding a bottled drink one with head tilted back and finger in her mouth and one with spiked hairendseq',
#   'startseqyoung people party in the streetsendseq',
#   'startseqgirls make faces as one takes a drink while they stand in a busy streetendseq',
#   'startseqwomen on the street drinking and posingendseq',
#   'startseqyoung women pose for the camera at a paradeendseq'],
#  '1130369873_d80a1aa59c': ['startseqbrown dog is running through neckdeep water carrying a tennis ballendseq',
#   'startseqbrown dog splashes in the water while carrying a ball in its mouthendseq',
#   'startseqbrown dog swims through water outdoors with a tennis ball in its mouthendseq',
#   'startseqred dog holding a ball splashes through vegetation filled waterendseq',
#   'startseqdog with tennis ball in mouth in water and bushesendseq'],
#  '1130401779_8c30182e3e': ['startseqbrown dogs are creating large splashes as they run in a riverendseq',
#   'startseqbrown dogs in the waterendseq',
#   'startseqbrown dogs running through waterendseq',
#   'startseqbrown dogs runs through the waterendseq',
#   'startseqdogs splash through the waterendseq'],
#  '1131155939_b4b457b05e': ['startseqblack dog runs into the ocean next to a pile of seaweedendseq',
#   'startseqblack lav runs into the water on the beach with swimmers in the distance and sea kelp in the foregroundendseq',
#   'startseqdog at the shore of an ocean with seaweed in foregroundendseq',
#   'startseqdog is running in the waves at the beachendseq',
#   'startseqpile of seaweed sits on the sand behind it a big black dog is running in the waterendseq'],
#  '1131340021_83f46b150a': ['startseqyoung boy runs while wearing sandalsendseq',
#   'startseqboy in a striped shirt and brown shorts is runningendseq',
#   'startseqlittle boy in a short sleeved shirt and shorts is running outsideendseq',
#   'startseqlittle boy is wearing a black pinstripe shirt and walking on a deckendseq',
#   'startseqboy running outside on the pavementendseq'],
#  '1131800850_89c7ffd477': ['startseqbrown and white dog stands outside while it snowsendseq',
#   'startseqdog is looking at something near the waterendseq',
#   'startseqfurry dog attempts to dry itself by shaking the water off its coatendseq',
#   'startseqwhite and brown dog shaking its self dryendseq',
#   'startseqlarge brown and white dog shakes off waterendseq'],
#  '1131804997_177c3c0640': ['startseqmen are sitting on the ground and going through their backpacksendseq',
#   'startseqmen sitting in front of a railing are looking at somethingendseq',
#   'startseqmen with backpacks placed in front of them sitting in front of a railingendseq',
#   'startseqmen with backpacks are sitting on cardboard along a railingendseq',
#   'startseqolder men with backpacks sit at a bus stationendseq'],
#  '1131932671_c8d17751b3': ['startseqboy is jumping on a bedendseq',
#   'startseqboy jumped up from the green bedendseq',
#   'startseqboy jumps from one bed to anotherendseq',
#   'startseqsmall child is jumping on a bedendseq',
#   'startseqboy in blue shorts is bouncing on the bedendseq'],
#  '1132772170_600610c5df': ['startseqchild leaping from bed to bed behind the back of a manendseq',
#   'startseqman is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the roomendseq',
#   'startseqman wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the backgroundendseq',
# ...
#   'startseqyoung girl climbs a rock wall in a purple dressendseq',
#   'startseqyoung girl wears a purple dressendseq'],
#  '2087317114_cf06df5aa5': ['startseqmani is kayaking down some calmer rapidsendseq',
#   'startseqman in a small kayak is floating down the riverendseq',
#   'startseqman in a yellow jacket is floating on the river in a green kayakendseq',
#   'startseqman smiles in his blue and green kayakendseq',
#   'startseqman wearing a helmet in a pyranha kayak floats down some river rapidsendseq'],
#  '2087640654_1a84577a44': ['startseqblonde dog is digging a deep hole in the ground and its tail is up in the airendseq',
#   'startseqdog half way in a hole in the groundendseq',
#   'startseqdog is digging a large hole in a yard to find somethingendseq',
#   'startseqdog is digging in the ground and half of his body is under the groundendseq',
#   'startseqrear end of an animal whose front end is undergroundendseq'],
#  '2088120475_d6318364f5': ['startseqperson dressed up as a snowman is walking through a crowd of peopleendseq',
#   'startseqcold people in the snowstorm one wearing a snowman headendseq',
#   'startseqpose for a picture in the snowendseq',
#   'startseqyoung people pose by a snowman in a red tieendseq',
#   'startseqcouples pose with a snowmanendseq'],
#  '2088460083_42ee8a595a': ['startseqbroken down hummer gets towed on a truck bedendseq',
#   'startseqdamaged vehicle is carried by a repair truck in a nighttime sceneendseq',
#   'startseqflat bed truck in a parking lot with an army vehicle on its bedendseq',
#   'startseqold beatup jeep being towed awayendseq',
#   'startseqsuv sits on the bed of a tow truck at nightendseq'],
#  '2088532947_c628e44c4a': ['startseqgirl in the white shirt has a bracelet on and has her arm around the girl in the peach shirtendseq',
#   'startseqtwo girls laid on the grass togetherendseq',
#   'startseqlittle girls are laying on the grass smilingendseq',
#   'startseqyoung girls holding each other on the grassy groundendseq',
#   'startseqyoung girls hug each other in the grassendseq'],
#  '2088910854_c6f8d4f5f9': ['startseqlarge man is wearing a headband with mistletoe attached to itendseq',
#   'startseqman in a sweatshirt and cap wears a flower on his headendseq',
#   'startseqman wearing a black knit cap with a red and white striped headband with a flower on topendseq',
#   'startseqman with a black ski cap and a red and white headband looks into the distanceendseq',
#   'startseqwearing a black hat with a christmas themeendseq'],
#  '2089122314_40d5739aef': ['startseqdog running with a newspaper in its mouthendseq',
#   'startseqdog runs down the street carrying a newspaperendseq',
#   'startseqdog with a newspaper in his mouth runs down a paved pathendseq',
#   'startseqfluffy tricolored dog is running down the road with a paper in its mouthendseq',
#   'startseqaustralian shepherd dog carrying a newspaper in his mouthendseq'],
#  '2089350172_dc2cf9fcf6': ['startseqblack dogs are swimming through some murky brown water one with a yellow object in its mouthendseq',
#   'startseqblack dogs swimming in dirty waterendseq',
#   'startseqdark dogs swimming and one of them has a ballendseq',
#   'startseqdogs are up to their necks in waterendseq',
#   'startseqdogs swim in the waterendseq'],
#  '2089426086_7acc98a3a8': ['startseqgirl in a hooded jacket presents a cake with candlesendseq',
#   'startseqgirl in a hood jacket holds a birthday cake with many candlesendseq',
#   'startseqgirl in a winter coat with a birthday cakeendseq',
#   'startseqgirl is holding a birthday cakeendseq',
#   'startseqyoung girl holding a cake with candles dressed in a heavy coatendseq'],
#  '2089442007_6fc798548c': ['startseqbrown dog is walking in the waterendseq',
#   'startseqbrown dog takes cautious steps in the calm waters with a sandy bottomendseq',
#   'startseqbrown dog wades in the waterendseq',
#   'startseqdog with red fur stands in a body of waterendseq',
#   'startseqlarge golden colored dog is walking through waterendseq'],
#  '2089539651_9e518ec7de': ['startseqhiker with two hiking poles stands on a hillside with a view of the city below himendseq',
#   'startseqhiker with two sticks is a standing on a path that is high up on a hillendseq',
#   'startseqhiking man stands on a cliff overlooking a cityendseq',
#   'startseqman hikes on a dirt path high above a cityendseq',
#   'startseqperson holding poles is standing on a rock ledge with bushes on each side overlooking mountainsendseq'],
#  '2089542487_b4c1ee7025': ['startseqhiker is ready to take on a rugged outdoor trailendseq',
#   'startseqlone hiker on a dirt hiking trail with a hat and sunglasses on with trees in the backgroundendseq',
#   'startseqman in shorts is hiking in a dry regionendseq',
#   'startseqman stops for a picture with the scenery during his hikeendseq',
#   'startseqman is posing for a picture in the desert wearing a green shirt and hat and holding a metal detectorendseq'],
#  '2089555297_95cf001fa7': ['startseqman in a hat with long sleeves and long pants stands overlooking a cityendseq',
#   'startseqman stands on a cliff overlooking a cityendseq',
#   'startseqman with a backpack and hat is standing by a high cliff where you can see for milesendseq',
#   'startseqstanding on top of a rock overlooking a townendseq',
#   'startseqman wearing a backpack and a hat stands on a ledge overlooking a cityendseq'],
#  '2090327868_9f99e2740d': ['startseqwoman a little boy and a tiny baby are standing in front of a cow statueendseq',
#   'startseqwoman and two small children posing in front of a large cow statueendseq',
#   'startseqwoman gives a baby to a small child to hold as they stand in front of a cow statueendseq',
#   'startseqwoman stands with two children near a decorated bull statueendseq',
#   'startseqwoman and children are standing next to a statue of a cowendseq'],
#  '2090339522_d30d2436f9': ['startseqman in a green hat is someplace up highendseq',
#   'startseqman in a green hat is taking a self portraitendseq',
#   'startseqman in a hat at a scenic overlookendseq',
#   'startseqman wearing a green canvas hat with a distnat city in the backgroundendseq',
#   'startseqwith green hate and sunglasses on a high up peakendseq'],
#  '2090386465_b6ebb7df2c': ['startseqwoman and man in winter gear standendseq',
#   'startseqadults wearing cold weather gearendseq',
#   'startseqpeople are wearing heavy clothingendseq',
#   'startseqpeople in winter clothingendseq',
#   'startseqwomen bundled up on a snowy dayendseq'],
#  '2090387793_274ab4cf7d': ['startseqboy wearing black walks down the street with his hands in fistsendseq',
#   'startseqteenage boy dressed in black stands on a snowy streetendseq',
#   'startseqteenage boy wearing all black tries to look tough with cheap jewelry onendseq',
#   'startseqyoung man wearing a black hat and jacket is walking outsideendseq',
#   'startseqrock teenager walks with a mean look on his faceendseq'],
#  '2090545563_a4e66ec76b': ['startseqboy laying face down on a skateboard is being pushed along the ground by another boyendseq',
#   'startseqgirls play on a skateboard in a courtyardendseq',
#   'startseqpeople play on a long skateboardendseq',
#   'startseqsmall children in red shirts playing on a skateboardendseq',
#   'startseqyoung children on a skateboard going across a sidewalkendseq'],
#  '2090723611_318031cfa5': ['startseqwalking in the grassy fieldendseq',
#   'startseqfluffy grey dog standing in grass in front of a brown dogendseq',
#   'startseqdog standing in some grass with his tongue hanging out and a tan dog in the backgroundendseq',
#   'startseqdogs of different breeds are standing in a pastureendseq',
#   'startseqdogs stand in the grassendseq'],
#  '2090997177_76d482b158': ['startseqblack dog bounds across the sandendseq',
#   'startseqdog walking across the desertendseq',
#   'startseqshort black dog is walking over a barren landscapeendseq',
#   'startseqsmall black dog running across the sandendseq',
#   'startseqsmall black dog walks in the sandendseq'],
#  '2091171488_c8512fec76': ['startseqfemale wearing pink gloves and a brown jacket is smiling in the snowendseq',
#   'startseqwoman standing in the snow with people in the backgroundendseq',
#   'startseqyoung woman in a spring coat and purple gloves stands in falling snowendseq',
#   'startseqyoung woman looks happy in winter clothes while it snowsendseq',
#   'startseqasian woman with pink gloves stands in the snowendseq'],
#  '2092177624_13ab757e8b': ['startseqboy in african clothing runs across a concrete wallendseq',
#   'startseqlittle boy with a green shirt is running on a rock ledgeendseq',
#   'startseqafrican boy in large green shirt is running barefoot along a wallendseq',
#   'startseqyoung boy dressed in green running along a smooth stone wall near a wooded areaendseq',
#   'startseqin green tunic on rock wallendseq'],
#  '2092419948_eea8001d0f': ['startseqlong haired man walking away beside a canal whist holding onto a railingendseq',
#   'startseqman walks down a path next to a waterwayendseq',
#   'startseqperson walks by some bluegreen water while holding a railendseq',
#   'startseqperson with a long ponytail walks along a waterway under a tunnelendseq',
#   'startseqman with long hair is walking along a storm drainendseq'],
#  '2092870249_90e3f1855b': ['startseqman lies on a street with his head and shoulders under a parked car that is jacked upendseq',
#   'startseqman looks under a car on a wet streetendseq',
#   'startseqman works on a carendseq',
#   'startseqperson lies half under a car facedownendseq',
#   'startseqperson underneath a car with a jackendseq'],
#  '2094323311_27d58b1513': ['startseqdog places his head on a man s faceendseq',
#   'startseqdog snuggles with a man in sunglassesendseq',
#   'startseqdog with a blue collar is licking a man who s wearing large tinted sunglassesendseq',
#   'startseqlarge brown dog with a blue collar is resting his chin on a man s faceendseq',
#   'startseqorange dog is licking a man wearing red sunglassesendseq'],
#  '2094543127_46d2f1fedf': ['startseqgirl holding a crocodile s mouth closedendseq',
#   'startseqgirl is posed over a statue of a dangerous animalendseq',
#   'startseqgirl sits on what appears to be a crocodileendseq',
#   'startseqgirl sitting on top of a crocodileendseq',
#   'startseqgirl with red hair is sitting on a crocodile holding its jawendseq'],
#  '2094810449_f8df9dcdf7': ['startseqboy stands in the ocean lifting up his shortsendseq',
#   'startseqchild in blue shorts is standing ankle deep in the waterendseq',
#   'startseqlittle boy in blue shorts glasses and a coat stands in the surfendseq',
#   'startseqkid is wearing a blue jacket and standing in shallow beach waterendseq',
#   'startseqsmall child wades ankle deep in the water on the shorelineendseq'],
#  '2095007523_591f255708': ['startseqbaby looks through his cribendseq',
#   'startseqbaby surrounded by some toys looks out of a playpenendseq',
#   'startseqin playpen with wide eyesendseq',
#   'startseqlooking through playpen bars at cameraendseq',
#   'startseqinfant is laying on its stomach in a crib looking up at the cameraendseq'],
#  '2095078658_c14ba89bc2': ['startseqdog runs through snow in front of the woodsendseq',
#   'startseqdog running in snowendseq',
#   'startseqdog runs through the snowendseq',
#   'startseqgerman shepherd dog is running through the snowendseq',
#   'startseqgerman shepherd is running through the white snowendseq'],
#  '2095435987_1b7591d214': ['startseqdog lying on its back in the sandendseq',
#   'startseqwhite and brown dog rolls on its back in the sandendseq',
#   'startseqdog rolls over to scratch its back in the sandendseq',
#   'startseqwhite and brown dog is rolling in the sandendseq',
#   'startseqwhite dog is on its back in the sand with paws in the airendseq'],
#  '2095444126_201ff9f222': ['startseqdog is shaking off waterendseq',
#   'startseqdog shakes his headendseq',
#   'startseqdog shakes off waterendseq',
#   'startseqdog shakes off water and gets contortedendseq',
#   'startseqdog is shaking water off of his bodyendseq'],
#  '2095478050_736c4d2d28': ['startseqman and a boy play music as little girls watchendseq',
#   'startseqman is playing a guitar with a child playing a harmonica while three young girls watchendseq',
#   'startseqchildren watch a man onstage playing guitarendseq',
#   'startseqlittle girls look on as a boy plays the harmonica with an adult guiutarist sitting beside himendseq',
#   'startseqlittle girls watch a bandendseq'],
#  '209605542_ca9cc52e7b': ['startseqclimber wearing a red headband is pulling himself up some grey rocks high above some green foliageendseq',
#   'startseqman in a headband climbing a rockendseq',
#   'startseqman with a red headband climbing a rock cliff looming over greeneryendseq',
#   'startseqclimbing a sheet rock faceendseq',
#   'startseqin red headband climbing a rockendseq'],
#  '2096771662_984441d20d': ['startseqman looks through his binoculars while another man holds a drinkendseq',
#   'startseqman with a thermos is standing next to a man who is gazing through binocularsendseq',
#   'startseqmen are standing together while one looks through binocularsendseq',
#   'startseqmen look out as one is holding binocularsendseq',
#   'startseqpeople standing next to each other with mountains in the distanceendseq'],
#  '2097398349_ff178b3f1b': ['startseqhiker waves to the camera as he standing in front of snowcapped mountainsendseq',
#   'startseqman stands on the snow near the mountainsendseq',
#   'startseqperson poses in the snowendseq',
#   'startseqperson stands in the snow at the top of a mountian arms raisedendseq',
#   'startseqskier in the mountainsendseq'],
#  '2097403787_77a154f5b9': ['startseqlone person standing on some rocks with large snowy mountains in the backgroundendseq',
#   'startseqman is standing on the rocky ground in front of the mountainendseq',
#   'startseqman standing in front of an icy mountainendseq',
#   'startseqperson is standing by the water in front of the snow topped mountainsendseq',
#   'startseqtraveller pauses in front of the mountain viewendseq'],
#  '2097407245_c798e0dcaf': ['startseqman in a winter jacket and knit cap stand with his arms up at his side in a snow landscapeendseq',
#   'startseqman is standing on dirt with his hands in the air with mountains and snow behind himendseq',
#   'startseqman raises his arms on rocky beachendseq',
#   'startseqlone man with fist in the air with large rocky mountains in the backgroundendseq',
#   'startseqwith outstretched arms standing on snowcovered rocksendseq'],
#  '2097420505_439f63c863': ['startseqmale hiker wearing a green jacket is posing next to a large glacierendseq',
#   'startseqman with a camera and an ice structure behind himendseq',
#   'startseqman with a camera crouching on iceendseq',
#   'startseqman with a camera kneels in front of a giant hill of snowendseq',
#   'startseqmountain climber prepares to take a photoendseq'],
#  '2097489021_ca1b9f5c3b': ['startseqgirl in a ballet fairy costume is touched by a wandendseq',
#   'startseqyoung girl performing the nutcrackerendseq',
#   'startseqlittle girl is standing on a stage dressed up as a pink fairyendseq',
#   'startseqtiny girl dressed in a butterfly ballet costume waves her wand near a nutcracker statueendseq',
#   'startseqgirl waving turquiose leotard and pink tutu with wings waving wandendseq'],
#  '2098174172_e57d86ea03': ['startseqhiker is posing in front of snowy mountainsendseq',
#   'startseqhiker is standing in before the mountain holding two walking sticksendseq',
#   'startseqman stands in front of snow covered mountainsendseq',
#   'startseqman with two ski poles stands near a mountaintopendseq',
#   'startseqman wears a green hat and jacket while standing in front of a mountainendseq'],
#  '2098418613_85a0c9afea': ['startseqbrown chow mix dog is standing in front of a van with euro plats in the middle of a messy yardendseq',
#   'startseqbrown dog standing in a muddy yardendseq',
#   'startseqbrown dogs walks near a green van and some junkendseq',
#   'startseqlarge brown dog stands in front of a green van in the yard of a houseendseq',
#   'startseqyellow dog is standing in front of a green car and next to a toiletendseq'],
#  ...}

# %%
from numpy import array
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import add
from keras.callbacks import ModelCheckpoint

def to_lines(descriptions):
    all_desc=list()
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

def create_tokenizer(descriptions):
    lines=to_lines(descriptions)
    tokenizer=Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

tokenizer=create_tokenizer(train_descriptions)
vocab_size=len(tokenizer.word_index)+1
print=('Vocabulary Size : %d' % vocab_size)

def max_length_fn(descriptions):
    lines=to_lines(descriptions)
    return max(len(d.split()) for d in lines)

def create_sequences(tokenizer,max_length,desc_list,photo):
    X1,X2,y=list(),list(),list()
    for desc in desc_list:
        seq=tokenizer.texts_to_sequences([desc])[0]
        for i in range(1,len(seq)):
            in_seq,out_seq=seq[:i],seq[i]
            in_seq=pad_sequences([in_seq],maxlen=max_length)[0]
            out_seq=to_categorical([out_seq],num_classes=vocab_size)[0]
            X1.append(photo)
            X2.append(in_seq)
            y.append(out_seq)
    return array(X1),array(X2),array(y)

def define_model(vocab_size,max_length):
    #feature Extractors
    inputs1=Input(shape=(4096,))
    fe1=Dropout(0.5)(inputs1)
    fe2=Dense(256,activation='relu')(fe1)
    #sequence models
    inputs2=Input(shape=(max_length,))
    se1=Embedding(vocab_size,256,mask_zero=True)(inputs2)
    se2=Dropout(0.5)(se1)
    se3=LSTM(256)(se2)
    #decoder model
    decoder1=add([fe2,se3])
    decoder2=Dense(256,activation='relu')(decoder1)
    outputs=Dense(vocab_size,activation='softmax')(decoder2)
    #tie it together[image, seq][word]
    model=Model(inputs=[inputs1,inputs2],outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    #summarize model
    print(model.summary())
    return model

# %%
#Progressive Loading Fuction
def data_generator(descriptions,photos,tokenizer,max_length):
    while 1:
        for key, desc_list in descriptions.items():
            photo=photo[keys][0]
            im_img,in_seq,out_word=create_sequences(tokenizer,max_length,desc_list,photo)
            yield[[in_img,in_seq],out_word]

# %%
    

# load training dataset (6K)
filename = 'captions.txt'
train = load_set(filename)


# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       6 # descriptions
#       7 train_descriptions = load_clean_descriptions('descriptions.txt', train)
# ----> 8 print('Descriptions: train=%d' % len(train_descriptions))
#       9 # photo features
#      10 train_features = load_photo_features('features.pkl', train)
#
# TypeError: 'str' object is not callable

# %%
# train the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
epochs = 20
steps = len(train_descriptions)
for i in range(epochs):
	# create the data generator
	generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
	# fit for one epoch
	model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
	# save model
	model.save('model_' + str(i) + '.h5')
